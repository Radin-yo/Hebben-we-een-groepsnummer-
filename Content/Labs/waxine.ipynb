# %% [markdown]
# ---
# authors: Freek Pols
# updated: december 3, 2025
# ---
# # Waxinekaarsje
#
# Als je een waxinekaarsje aan steekt en er een glas overheen zet, zal het kaarsje uit gaan.
# Als je dat waxinekaarsje laat drijven op water terwijl je er het glas er overheen zet, zal het water in het glas stijgen.
# Op het internet zwerven er verschillende verklaringen voor dit fenomeen rond.
# 1. Het kaarsje verbruikt zuurstof, waardoor er een vacuüm ontstaat en het water omhoog wordt gezogen.
# 2. Het kaarsje verwarmt de lucht in het glas, waardoor de lucht uitzet. Wanneer de kaars dooft koelt de lucht af waardoor de druk afneemt en er water omhoog wordt gezogen.
# 3. Bij het verbranden van de kaars ontstaan er waterdamp en koolstofdioxide. De waterdamp condenseert aan de binnenkant van het glas, waardoor er minder gas in het glas is en de druk afneemt. Hierdoor wordt het water omhoog gezogen.
#
# ```{exercise}
# Onderzoek welke verklaring het meest waarschijnlijk is en leg uit waarom de andere verklaringen minder waarschijnlijk zijn.
# ```

# %% [raw]
# 1.
# Deze verklaring is zeer onwaarschijnlijk. Het zuurstof dat het kaarsje verbruikt wordt omgezet in waterdamp en koolstofdioxide. Als er alleen CO2 ontstond zouden het aantal deeltjes gelijk blijven, maar omdat er ook H2O ontstaat moeten er wel meer deeltjes komen. De ideale gaswet zegt ons dat meer deeltjes zorgen voor een hogere druk.
#
# 2.
# Dit zal alleen effect hebben als, terwijl de lucht verwarmt, er een gedeelte van de lucht uit het glas ontsnapt. Dit is dus alleen een waarschijnlijke verklaring als je bubbeltjes ziet.
#
# 3.
# Neem de uitleg bij verklaring 1. Als de O2 wordt omgezet in CO2 en H2O, en de H2O vervolgens condenseert (en dus een verwaarloosbare volume in beslag neemt), zijn er minder gasdeeltjes, wat ervoor zorgt dat de druk afneemt. Als er waterdamp te zien is dit de meest waarschijnlijke verklaring.
#
# Meting:
# We hebben 150ml water genomen, met in het midden een aangestoken kaarsje. Hieroverheen is een afgesloten glazen buis geplaatst. Wanneer de buis net geplaatst is komt het water 3 ml hoog (455-452). Zodra het kaarsje gedooft is, komt het water 56 ml hoog (455-399). Op de glazen buis was waterdamp te zien. Hieruit is op te nemen dat verklaring 3 het meest waarschijnlijk is.
